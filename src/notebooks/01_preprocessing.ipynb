# %% [markdown]
# ## converting json to df

# %%
import pandas as pd

# %%
df = pd.read_json("/Users/asawaribrijeshtalathi/Downloads/AI-Driven-Medical-Devices-Intelligent-System 3/src/preprocessing/merged.json")  
df.head(5)
# '/home/sunbeam/Desktop/AI-Driven-Medical-Devices-Intelligent-System/src/preprocessing/ - linux path
# Out:
#                                           source_url     patent_id  \
# 0  https://patents.google.com/patent/CN102708128A/en  CN102708128A
# 1  https://patents.google.com/patent/CN102708128A/en  CN102708128A
# 2  https://patents.google.com/patent/CN102708128A/en  CN102708128A
# 3  https://patents.google.com/patent/CN102708128A/en  CN102708128A
# 4  https://patents.google.com/patent/CN102708128A/en  CN102708128A
#
#                                                title  \
# 0  Methods and systems for receiving, mapping and...
# 1  Methods and systems for receiving, mapping and...
# 2  Methods and systems for receiving, mapping and...
# 3  Methods and systems for receiving, mapping and...
# 4  Methods and systems for receiving, mapping and...
#
#                                             title_en  \
# 0  Methods and systems for receiving, mapping and...
# 1  Methods and systems for receiving, mapping and...
# 2  Methods and systems for receiving, mapping and...
# 3  Methods and systems for receiving, mapping and...
# 4  Methods and systems for receiving, mapping and...
#
#                                             abstract  \
# 0  The invention is entitled "Methods and systems...
# 1  The invention is entitled "Methods and systems...
# 2  The invention is entitled "Methods and systems...
# 3  The invention is entitled "Methods and systems...
# 4  The invention is entitled "Methods and systems...
#
#                                          abstract_en  \
# 0  The invention is entitled "Methods and systems...
# 1  The invention is entitled "Methods and systems...
# 2  The invention is entitled "Methods and systems...
# 3  The invention is entitled "Methods and systems...
# 4  The invention is entitled "Methods and systems...
#
#                                          description  \
# 0  The invention is entitled "Methods and systems...
# 1  The invention is entitled "Methods and systems...
# 2  The invention is entitled "Methods and systems...
# 3  The invention is entitled "Methods and systems...
# 4  The invention is entitled "Methods and systems...
#
#                                               claims  \
# 0  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...
# 1  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...
# 2  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...
# 3  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...
# 4  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...
#
#                                            claims_en filing_date  ...  \
# 0  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21  ...
# 1  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21  ...
# 2  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21  ...
# 3  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21  ...
# 4  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21  ...
#
#      assignee_original          assignee_en  inventors    ipc_codes  \
# 0  General Electric Co  General Electric Co       None  [G16H10/60]
# 1  General Electric Co  General Electric Co       None  [G16H10/60]
# 2  General Electric Co  General Electric Co       None  [G16H10/60]
# 3  General Electric Co  General Electric Co       None  [G16H10/60]
# 4  General Electric Co  General Electric Co       None  [G16H10/60]
#
#      cpc_codes claim_count independent_claim_count backward_citation_count  \
# 0  [G16H10/60]          22                       4                      60
# 1  [G16H10/60]          22                       4                      60
# 2  [G16H10/60]          22                       4                      60
# 3  [G16H10/60]          22                       4                      60
# 4  [G16H10/60]          22                       4                      60
#
#    forward_citation_count  legal_status
# 0                       0        Status
# 1                       0        Status
# 2                       0        Status
# 3                       0        Status
# 4                       0        Status
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18970 entries, 0 to 18969
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   source_url               18970 non-null  object
#  1   patent_id                18970 non-null  object
#  2   title                    18970 non-null  object
#  3   title_en                 18970 non-null  object
#  4   abstract                 18434 non-null  object
#  5   abstract_en              18434 non-null  object
#  6   description              18486 non-null  object
#  7   claims                   18970 non-null  object
#  8   claims_en                18970 non-null  object
#  9   filing_date              18964 non-null  object
#  10  publication_date         18964 non-null  object
#  11  country                  18970 non-null  object
#  12  language                 0 non-null      float64
#  13  assignee_original        18948 non-null  object
#  14  assignee_en              18948 non-null  object
#  15  inventors                8011 non-null   object
#  16  ipc_codes                18970 non-null  object
#  17  cpc_codes                18970 non-null  object
#  18  claim_count              18970 non-null  int64
#  19  independent_claim_count  18970 non-null  int64
#  20  backward_citation_count  18970 non-null  int64
#  21  forward_citation_count   18970 non-null  int64
#  22  legal_status             18330 non-null  object
# dtypes: float64(1), int64(4), object(18)
# memory usage: 3.3+ MB

# %%
df.columns
# Out:
# Index(['source_url', 'patent_id', 'title', 'title_en', 'abstract',
#        'abstract_en', 'description', 'claims', 'claims_en', 'filing_date',
#        'publication_date', 'country', 'language', 'assignee_original',
#        'assignee_en', 'inventors', 'ipc_codes', 'cpc_codes', 'claim_count',
#        'independent_claim_count', 'backward_citation_count',
#        'forward_citation_count', 'legal_status'],
#       dtype='object')

# %%
df.shape
# Out:
# (18970, 23)

# %% [markdown]
# ### Missing Value Analysis

# %% [markdown]
# ##

# %%
missing = df.isnull().sum()

missing_df = pd.DataFrame({
    'Missing Count': missing,
    'Missing %': round((missing/len(df))*100,2)
})

print(missing_df)
# Out:
#                          Missing Count  Missing %
# source_url                           0       0.00
# patent_id                            0       0.00
# title                                0       0.00
# title_en                             0       0.00
# abstract                           536       2.83
# abstract_en                        536       2.83
# description                        484       2.55
# claims                               0       0.00
# claims_en                            0       0.00
# filing_date                          6       0.03
# publication_date                     6       0.03
# country                              0       0.00
# language                         18970     100.00
# assignee_original                   22       0.12
# assignee_en                         22       0.12
# inventors                        10959      57.77
# ipc_codes                            0       0.00
# cpc_codes                            0       0.00
# claim_count                          0       0.00
# independent_claim_count              0       0.00
# backward_citation_count              0       0.00
# forward_citation_count               0       0.00
# legal_status                       640       3.37

# %% [markdown]
# ### drop unrequired columns

# %%
df.drop(columns=['claims_en', 'inventors'], errors='ignore', inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18970 entries, 0 to 18969
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   source_url               18970 non-null  object
#  1   patent_id                18970 non-null  object
#  2   title                    18970 non-null  object
#  3   title_en                 18970 non-null  object
#  4   abstract                 18434 non-null  object
#  5   abstract_en              18434 non-null  object
#  6   description              18486 non-null  object
#  7   claims                   18970 non-null  object
#  8   filing_date              18964 non-null  object
#  9   publication_date         18964 non-null  object
#  10  country                  18970 non-null  object
#  11  language                 0 non-null      float64
#  12  assignee_original        18948 non-null  object
#  13  assignee_en              18948 non-null  object
#  14  ipc_codes                18970 non-null  object
#  15  cpc_codes                18970 non-null  object
#  16  claim_count              18970 non-null  int64
#  17  independent_claim_count  18970 non-null  int64
#  18  backward_citation_count  18970 non-null  int64
#  19  forward_citation_count   18970 non-null  int64
#  20  legal_status             18330 non-null  object
# dtypes: float64(1), int64(4), object(16)
# memory usage: 3.0+ MB

# %%
# Handle claims_clean first

# Only 8 records are missing.

# For BERTopic, claims_clean contributes to your combined_text.

# Check those 8 rows:

# df[df["claims_clean"].isnull()][
#     ["patent_id","title","abstract","description"]
# ]

# %%
# Handle abstract and description

# Do not delete these 392 rows.

# For patent discovery, missing description is acceptable.

# Fill with empty string:

text_columns = [
    "abstract",
    "description",
    "abstract_en"
]

for col in text_columns:
    df[col] = df[col].fillna("")

# %%
#df["claims_clean"].isnull().sum()

# %%
df[text_columns].isnull().sum()
# Out:
# abstract       0
# description    0
# abstract_en    0
# dtype: int64

# %%
df["legal_status"].value_counts(dropna=False)
# Out:
# legal_status
# Status        16479
# None            640
# Pending          30
# Active           22
# Granted          11
#               ...
# 2023-05-06        1
# 2021-05-07        1
# 2025-07-29        1
# 2024-09-09        1
# 2024-04-11        1
# Name: count, Length: 1316, dtype: int64

# %%
df["legal_status"] = (
    df["legal_status"]
    .fillna("Unknown")
)

# %%
missing = (
    df.isnull()
      .sum()
      .sort_values(ascending=False)
)

missing[missing>0]
# Out:
# language             18970
# assignee_original       22
# assignee_en             22
# filing_date              6
# publication_date         6
# dtype: int64

# %%
# empty_text = df[
#     df["combined_text"].str.strip()==""
# ]

# print(len(empty_text))

# %% [markdown]
# ### handling claims column where the claims contain non-english claims

# %%
df_before = len(df)
df_before
# Out:
# 18970

# %%
import langid

df["detected_language"] = df["claims"].apply(lambda x: langid.classify(str(x))[0])

# %%
# df[df["detected_language"] != "en"][["detected_language", "claims"]].to_csv('/home/sunbeam/Desktop/AI-Driven-Medical-Devices-Intelligent-System/src/preprocessing/non_english_claims.csv', index=False)
df[df["detected_language"] != "en"][["detected_language", "claims"]].to_csv('/Users/asawaribrijeshtalathi/Downloads/AI-Driven-Medical-Devices-Intelligent-System 3/src/preprocessing/non_english_claims.csv', index=False)

# %%
non_english = df[df["detected_language"] != "en"]

print("Number of non-English rows:", len(non_english))
# Out:
# Number of non-English rows: 6413

# %%
non_english[["detected_language", "claims"]].head()
# Out:
#   detected_language                                             claims
# 0                zh  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...
# 1                zh  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...
# 2                zh  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...
# 3                zh  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...
# 4                zh  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...

# %% [markdown]
# ### Segment-wise Language Filtering
# - Instead of classifying the entire claims column, classify small segments and keep only the English ones.

# %% [markdown]
# #### Step 1: Split the claim into segments
#
# Split using:
#
# newline (\n)
# semicolon (;)
# period (.)
#
# These are natural separators in patent claims.

# %%
import re

def split_segments(text):
    if pd.isna(text):
        return []

    segments = re.split(r'[\n;.]', str(text))

    return [s.strip() for s in segments if len(s.strip()) > 10]

# %% [markdown]
# #### Step 2: Keep only English segments
#
# Instead of langid, use an English character ratio.

# %%
import re

def is_english(segment, threshold=0.75):

    english = len(re.findall(r'[A-Za-z]', segment))

    cjk = len(re.findall(r'[\u3040-\u30FF\u3400-\u9FFF\uAC00-\uD7AF]', segment))

    total = english + cjk

    if total == 0:
        return False

    return english / total >= threshold

# %%
# rebuild the claims

def extract_english_claims(text):

    segments = split_segments(text)

    english_segments = []

    for seg in segments:

        if is_english(seg):

            english_segments.append(seg)

    return ". ".join(english_segments)

# %%
df["claims_clean"] = df["claims"].apply(extract_english_claims)

# %%
df[
    ["claims", "claims_clean"]
].sample(20, random_state=42)
# Out:
#                                                   claims  \
# 1862   人の行動を検出するセンサと、 前記センサの検出情報に基づき機械学習モデルにより人の行動を予測...
# 4049   1. An apparatus, comprising: an implantable de...
# 17622  1. Yang-establishing health tonic wine is char...
# 13684  1. honey citron tea with health care, it is ch...
# 4693   1. A medical alert message handling method for...
# 18391  1. apple health-care dried meat and a processi...
# 3353   1.一种基于人工智能的自动化数据处理方法，其特征在于，包括以下步骤： 1. An autom...
# 12428  1.一种防治老年痴呆症的益生菌活性保健液,其特征在于：所述保健液组份及重量份数配比为：光合细...
# 9430   一种人体活动监测与指导方法，其特征在于，所述人体活动监测与指导方法包括以下步骤： A hum...
# 5496   1. a kind of healthy growth intelligent detect...
# 16234  1 . A medical care support apparatus comprisin...
# 4373   一种基于文本任务的言语障碍评估系统，其特征在于，包含： A speech disorder ...
# 18755  1. Camellia nitidissima health-care milk powde...
# 5031   A kind of method 1. tele-medicine based on thi...
# 18936  1. a health-care maltitol grain cake, it is ch...
# 13152  1 . A computer system comprising: at least one...
# 7976   Mobiles Mess-, Speicher- und Kommunikationsger...
# 6373   컴퓨터 시스템에서 구현되는 3차원 생물학적 정보 처리 방법에 있어서, 3차원 몸체모...
# 2444   1. A method of training a medical language mod...
# 13177  1.一种保健型棉/石墨烯锦纶交织绸衬衫面料的加工方法，其特征在于：所述保健型棉/石墨烯锦纶交...
#
#                                             claims_clean
# 1862   Alert mode operation control unit that determi...
# 4049   An apparatus, comprising: an implantable devic...
# 17622  Yang-establishing health tonic wine is charact...
# 13684  honey citron tea with health care, it is chara...
# 4693   A medical alert message handling method for a ...
# 18391  apple health-care dried meat and a processing ...
# 3353   An automated data processing method based on a...
# 12428  A probiotic active health care solution for pr...
# 9430   一种人体活动监测与指导方法，其特征在于，所述人体活动监测与指导方法包括以下步骤： A hum...
# 5496   a kind of healthy growth intelligent detection...
# 16234  A medical care support apparatus comprising pr...
# 4373   一种基于文本任务的言语障碍评估系统，其特征在于，包含： A speech disorder ...
# 18755  Camellia nitidissima health-care milk powder i...
# 5031   A kind of method 1. tele-medicine based on thi...
# 18936  a health-care maltitol grain cake, it is chara...
# 13152  A computer system comprising: at least one net...
# 7976   Mobiles Mess-, Speicher- und Kommunikationsger...
# 6373   A three-dimensional biological information pro...
# 2444   A method of training a medical language model,...
# 13177  a processing method of health care type cotton...

# %%
df[["patent_id", "claims", "claims_clean"]].to_csv(
    "claims_comparison.csv",
    index=False,
    encoding="utf-8-sig"
)

# %%
df.columns
# Out:
# Index(['source_url', 'patent_id', 'title', 'title_en', 'abstract',
#        'abstract_en', 'description', 'claims', 'filing_date',
#        'publication_date', 'country', 'language', 'assignee_original',
#        'assignee_en', 'ipc_codes', 'cpc_codes', 'claim_count',
#        'independent_claim_count', 'backward_citation_count',
#        'forward_citation_count', 'legal_status', 'detected_language',
#        'claims_clean'],
#       dtype='object')

# %% [markdown]
# ### drop completely missing values

# %%
# Modify the original DataFrame directly
df.drop(columns=['language', 'inventors'], errors='ignore', inplace=True)
df.columns
# Out:
# Index(['source_url', 'patent_id', 'title', 'title_en', 'abstract',
#        'abstract_en', 'description', 'claims', 'filing_date',
#        'publication_date', 'country', 'assignee_original', 'assignee_en',
#        'ipc_codes', 'cpc_codes', 'claim_count', 'independent_claim_count',
#        'backward_citation_count', 'forward_citation_count', 'legal_status',
#        'detected_language', 'claims_clean'],
#       dtype='object')

# %% [markdown]
# #### handling missing abstaracts

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,4))
sns.heatmap(df.isnull(), cbar=False)
plt.show()

# %% [markdown]
# ### Duplicate Analysis

# %%
# inspecting data types of columns
print(df.dtypes)
# Out:
# source_url                 object
# patent_id                  object
# title                      object
# title_en                   object
# abstract                   object
# abstract_en                object
# description                object
# claims                     object
# filing_date                object
# publication_date           object
# country                    object
# assignee_original          object
# assignee_en                object
# ipc_codes                  object
# cpc_codes                  object
# claim_count                 int64
# independent_claim_count     int64
# backward_citation_count     int64
# forward_citation_count      int64
# legal_status               object
# detected_language          object
# claims_clean               object
# dtype: object

# %%
# checking type of values in each column
for col in df.columns:
    print(col, type(df[col].iloc[0]))
# Out:
# source_url <class 'str'>
# patent_id <class 'str'>
# title <class 'str'>
# title_en <class 'str'>
# abstract <class 'str'>
# abstract_en <class 'str'>
# description <class 'str'>
# claims <class 'str'>
# filing_date <class 'str'>
# publication_date <class 'str'>
# country <class 'str'>
# assignee_original <class 'str'>
# assignee_en <class 'str'>
# ipc_codes <class 'list'>
# cpc_codes <class 'list'>
# claim_count <class 'numpy.int64'>
# independent_claim_count <class 'numpy.int64'>
# backward_citation_count <class 'numpy.int64'>
# forward_citation_count <class 'numpy.int64'>
# legal_status <class 'str'>
# detected_language <class 'str'>
# claims_clean <class 'str'>

# %%
# finding duplicates using unique identifier patent_id
df.duplicated(subset='patent_id').sum()
# Out:
# np.int64(610)

# %%
# display all duplicate records
duplicates = df[df.duplicated(subset='patent_id', keep=False)]

duplicates.head(10)
# Out:
#                                           source_url     patent_id  \
# 0  https://patents.google.com/patent/CN102708128A/en  CN102708128A
# 1  https://patents.google.com/patent/CN102708128A/en  CN102708128A
# 2  https://patents.google.com/patent/CN102708128A/en  CN102708128A
# 3  https://patents.google.com/patent/CN102708128A/en  CN102708128A
# 4  https://patents.google.com/patent/CN102708128A/en  CN102708128A
# 5  https://patents.google.com/patent/CN102708128A/en  CN102708128A
# 6  https://patents.google.com/patent/CN102708128A/en  CN102708128A
# 7  https://patents.google.com/patent/CN102708128A/en  CN102708128A
# 8  https://patents.google.com/patent/CN102708128A/en  CN102708128A
# 9  https://patents.google.com/patent/CN102708128A/en  CN102708128A
#
#                                                title  \
# 0  Methods and systems for receiving, mapping and...
# 1  Methods and systems for receiving, mapping and...
# 2  Methods and systems for receiving, mapping and...
# 3  Methods and systems for receiving, mapping and...
# 4  Methods and systems for receiving, mapping and...
# 5  Methods and systems for receiving, mapping and...
# 6  Methods and systems for receiving, mapping and...
# 7  Methods and systems for receiving, mapping and...
# 8  Methods and systems for receiving, mapping and...
# 9  Methods and systems for receiving, mapping and...
#
#                                             title_en  \
# 0  Methods and systems for receiving, mapping and...
# 1  Methods and systems for receiving, mapping and...
# 2  Methods and systems for receiving, mapping and...
# 3  Methods and systems for receiving, mapping and...
# 4  Methods and systems for receiving, mapping and...
# 5  Methods and systems for receiving, mapping and...
# 6  Methods and systems for receiving, mapping and...
# 7  Methods and systems for receiving, mapping and...
# 8  Methods and systems for receiving, mapping and...
# 9  Methods and systems for receiving, mapping and...
#
#                                             abstract  \
# 0  The invention is entitled "Methods and systems...
# 1  The invention is entitled "Methods and systems...
# 2  The invention is entitled "Methods and systems...
# 3  The invention is entitled "Methods and systems...
# 4  The invention is entitled "Methods and systems...
# 5  The invention is entitled "Methods and systems...
# 6  The invention is entitled "Methods and systems...
# 7  The invention is entitled "Methods and systems...
# 8  The invention is entitled "Methods and systems...
# 9  The invention is entitled "Methods and systems...
#
#                                          abstract_en  \
# 0  The invention is entitled "Methods and systems...
# 1  The invention is entitled "Methods and systems...
# 2  The invention is entitled "Methods and systems...
# 3  The invention is entitled "Methods and systems...
# 4  The invention is entitled "Methods and systems...
# 5  The invention is entitled "Methods and systems...
# 6  The invention is entitled "Methods and systems...
# 7  The invention is entitled "Methods and systems...
# 8  The invention is entitled "Methods and systems...
# 9  The invention is entitled "Methods and systems...
#
#                                          description  \
# 0  The invention is entitled "Methods and systems...
# 1  The invention is entitled "Methods and systems...
# 2  The invention is entitled "Methods and systems...
# 3  The invention is entitled "Methods and systems...
# 4  The invention is entitled "Methods and systems...
# 5  The invention is entitled "Methods and systems...
# 6  The invention is entitled "Methods and systems...
# 7  The invention is entitled "Methods and systems...
# 8  The invention is entitled "Methods and systems...
# 9  The invention is entitled "Methods and systems...
#
#                                               claims filing_date  \
# 0  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21
# 1  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21
# 2  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21
# 3  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21
# 4  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21
# 5  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21
# 6  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21
# 7  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21
# 8  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21
# 9  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21
#
#   publication_date  ...          assignee_en    ipc_codes    cpc_codes  \
# 0       2012-10-03  ...  General Electric Co  [G16H10/60]  [G16H10/60]
# 1       2012-10-03  ...  General Electric Co  [G16H10/60]  [G16H10/60]
# 2       2012-10-03  ...  General Electric Co  [G16H10/60]  [G16H10/60]
# 3       2012-10-03  ...  General Electric Co  [G16H10/60]  [G16H10/60]
# 4       2012-10-03  ...  General Electric Co  [G16H10/60]  [G16H10/60]
# 5       2012-10-03  ...  General Electric Co  [G16H10/60]  [G16H10/60]
# 6       2012-10-03  ...  General Electric Co  [G16H10/60]  [G16H10/60]
# 7       2012-10-03  ...  General Electric Co  [G16H10/60]  [G16H10/60]
# 8       2012-10-03  ...  General Electric Co  [G16H10/60]  [G16H10/60]
# 9       2012-10-03  ...  General Electric Co  [G16H10/60]  [G16H10/60]
#
#   claim_count independent_claim_count  backward_citation_count  \
# 0          22                       4                       60
# 1          22                       4                       60
# 2          22                       4                       60
# 3          22                       4                       60
# 4          22                       4                       60
# 5          22                       4                       60
# 6          22                       4                       60
# 7          22                       4                       60
# 8          22                       4                       60
# 9          22                       4                       60
#
#    forward_citation_count  legal_status  detected_language  \
# 0                       0        Status                 zh
# 1                       0        Status                 zh
# 2                       0        Status                 zh
# 3                       0        Status                 zh
# 4                       0        Status                 zh
# 5                       0        Status                 zh
# 6                       0        Status                 zh
# 7                       0        Status                 zh
# 8                       0        Status                 zh
# 9                       0        Status                 zh
#
#                                         claims_clean
# 0  A computer-implemented method of receiving dat...
# 1  A computer-implemented method of receiving dat...
# 2  A computer-implemented method of receiving dat...
# 3  A computer-implemented method of receiving dat...
# 4  A computer-implemented method of receiving dat...
# 5  A computer-implemented method of receiving dat...
# 6  A computer-implemented method of receiving dat...
# 7  A computer-implemented method of receiving dat...
# 8  A computer-implemented method of receiving dat...
# 9  A computer-implemented method of receiving dat...
#
# [10 rows x 22 columns]

# %%
# sort them by patent id
# duplicates = duplicates.sort_values("patent_id")

# duplicates

# %%
# Count how many unique patent_ids are duplicated
duplicates["patent_id"].nunique()
# Out:
# 112

# %%
# Show only patent IDs with duplicates
duplicate_ids = df.loc[
    df.duplicated(subset='patent_id', keep=False),
    "patent_id"
].unique()

duplicate_ids
# Out:
# array(['CN102708128A', 'CN109637674B', 'KR101817241B1', 'US20240257932A1',
#        'CN117894421A', 'CN117649941A', 'KR102501896B1', 'US20200097910A1',
#        'US20200365258A1', 'KR102512744B1', 'US20230197227A1',
#        'US20230260665A1', 'US10698983B2', 'CN109544268B',
#        'US20190206518A1', 'US20180137943A1', 'US10950354B1',
#        'US20210313022A1', 'CN112786219B', 'KR101710460B1',
#        'US20220384061A1', 'US12334227B2', 'AU2023204667B2',
#        'CN115996668B', 'CN115410707B', 'CN108492878A', 'JP7210260B2',
#        'CN109524089B', 'US20220223259A1', 'US11211165B1', 'CN119339899A',
#        'US11901073B2', 'US20230317225A1', 'US20200129094A1',
#        'US12381002B2', 'US12068062B2', 'WO2020199113A1',
#        'US20220157451A1', 'US12599342B2', 'KR102483932B1', 'CN114005528A',
#        'WO2025085872A1', 'CN110534186A', 'US20230020908A1',
#        'US20230070895A1', 'CN116485335A', 'KR20190065822A',
#        'CN118299013A', 'US20210319893A1', 'US12568132B2',
#        'US20220101996A1', 'KR102681198B1', 'US12224052B2',
#        'US20210020305A1', 'CN112948351A', 'US20210004482A1',
#        'US20240062877A1', 'US20230395215A1', 'WO2021247272A1',
#        'CN111341400A', 'CN110826913A', 'CN118445382A', 'KR20190069046A',
#        'CN106361285A', 'US12608203B2', 'WO2022178447A1',
#        'US20260051379A1', 'US10629310B2', 'KR101992944B1',
#        'US20250104156A1', 'US20190295694A1', 'CA3093698C',
#        'KR102430758B1', 'KR102479107B1', 'CN121439092A',
#        'US20190115111A1', 'KR20220022952A', 'CN109243622A',
#        'KR102330705B1', 'CN114783627B', 'US20240194314A1',
#        'WO2021199265A1', 'KR101906398B1', 'KR20210088103A',
#        'KR102668110B1', 'US12614641B2', 'US20220230741A1', 'US12042451B2',
#        'US12135818B1', 'US11978563B1', 'KR102613649B1', 'US12073929B2',
#        'US20210027885A1', 'KR20170011703A', 'US20210366591A1',
#        'US20210366604A1', 'KR102796603B1', 'KR102043678B1',
#        'US10832823B1', 'KR102433466B1', 'CN105930641A', 'CN114628048A',
#        'US11593777B2', 'KR20200059800A', 'US20240396995A1',
#        'KR20160139802A', 'CN105996996B', 'KR20230043390A',
#        'US20190287670A1', 'CN119541907A', 'US12586690B2', 'CN110675946A'],
#       dtype=object)

# %%
# See how many times each patent_id appears
duplicates["patent_id"].value_counts()
# Out:
# patent_id
# CN102708128A       500
# CN109637674B         2
# KR101906398B1        2
# WO2021199265A1       2
# US20240194314A1      2
#                   ...
# US20200129094A1      2
# US20230317225A1      2
# US11901073B2         2
# CN119339899A         2
# CN110675946A         2
# Name: count, Length: 112, dtype: int64

# %%
# Save duplicate records to a separate JSON/CSV
duplicates.to_json(
    "duplicate_patents.json",
    orient="records",
    indent=4
)

# %%
# Remove duplicates while keeping the first occurrence

# If you've confirmed they're true duplicates:

df = df.drop_duplicates(subset="patent_id", keep="first")

# %%
duplicates.groupby("patent_id").size().sort_values(ascending=False)
# Out:
# patent_id
# CN102708128A       500
# AU2023204667B2       2
# US12586690B2         2
# US20200365258A1      2
# US20200129094A1      2
#                   ...
# KR101992944B1        2
# KR101906398B1        2
# KR101817241B1        2
# KR101710460B1        2
# WO2025085872A1       2
# Length: 112, dtype: int64

# %%
duplicates[duplicates["patent_id"] == "CN102708128A"]
# Out:
#                                             source_url     patent_id  \
# 0    https://patents.google.com/patent/CN102708128A/en  CN102708128A
# 1    https://patents.google.com/patent/CN102708128A/en  CN102708128A
# 2    https://patents.google.com/patent/CN102708128A/en  CN102708128A
# 3    https://patents.google.com/patent/CN102708128A/en  CN102708128A
# 4    https://patents.google.com/patent/CN102708128A/en  CN102708128A
# ..                                                 ...           ...
# 495  https://patents.google.com/patent/CN102708128A/en  CN102708128A
# 496  https://patents.google.com/patent/CN102708128A/en  CN102708128A
# 497  https://patents.google.com/patent/CN102708128A/en  CN102708128A
# 498  https://patents.google.com/patent/CN102708128A/en  CN102708128A
# 499  https://patents.google.com/patent/CN102708128A/en  CN102708128A
#
#                                                  title  \
# 0    Methods and systems for receiving, mapping and...
# 1    Methods and systems for receiving, mapping and...
# 2    Methods and systems for receiving, mapping and...
# 3    Methods and systems for receiving, mapping and...
# 4    Methods and systems for receiving, mapping and...
# ..                                                 ...
# 495  Methods and systems for receiving, mapping and...
# 496  Methods and systems for receiving, mapping and...
# 497  Methods and systems for receiving, mapping and...
# 498  Methods and systems for receiving, mapping and...
# 499  Methods and systems for receiving, mapping and...
#
#                                               title_en  \
# 0    Methods and systems for receiving, mapping and...
# 1    Methods and systems for receiving, mapping and...
# 2    Methods and systems for receiving, mapping and...
# 3    Methods and systems for receiving, mapping and...
# 4    Methods and systems for receiving, mapping and...
# ..                                                 ...
# 495  Methods and systems for receiving, mapping and...
# 496  Methods and systems for receiving, mapping and...
# 497  Methods and systems for receiving, mapping and...
# 498  Methods and systems for receiving, mapping and...
# 499  Methods and systems for receiving, mapping and...
#
#                                               abstract  \
# 0    The invention is entitled "Methods and systems...
# 1    The invention is entitled "Methods and systems...
# 2    The invention is entitled "Methods and systems...
# 3    The invention is entitled "Methods and systems...
# 4    The invention is entitled "Methods and systems...
# ..                                                 ...
# 495  The invention is entitled "Methods and systems...
# 496  The invention is entitled "Methods and systems...
# 497  The invention is entitled "Methods and systems...
# 498  The invention is entitled "Methods and systems...
# 499  The invention is entitled "Methods and systems...
#
#                                            abstract_en  \
# 0    The invention is entitled "Methods and systems...
# 1    The invention is entitled "Methods and systems...
# 2    The invention is entitled "Methods and systems...
# 3    The invention is entitled "Methods and systems...
# 4    The invention is entitled "Methods and systems...
# ..                                                 ...
# 495  The invention is entitled "Methods and systems...
# 496  The invention is entitled "Methods and systems...
# 497  The invention is entitled "Methods and systems...
# 498  The invention is entitled "Methods and systems...
# 499  The invention is entitled "Methods and systems...
#
#                                            description  \
# 0    The invention is entitled "Methods and systems...
# 1    The invention is entitled "Methods and systems...
# 2    The invention is entitled "Methods and systems...
# 3    The invention is entitled "Methods and systems...
# 4    The invention is entitled "Methods and systems...
# ..                                                 ...
# 495  The invention is entitled "Methods and systems...
# 496  The invention is entitled "Methods and systems...
# 497  The invention is entitled "Methods and systems...
# 498  The invention is entitled "Methods and systems...
# 499  The invention is entitled "Methods and systems...
#
#                                                 claims filing_date  \
# 0    1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21
# 1    1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21
# 2    1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21
# 3    1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21
# 4    1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21
# ..                                                 ...         ...
# 495  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21
# 496  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21
# 497  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21
# 498  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21
# 499  1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21
#
#     publication_date  ...          assignee_en    ipc_codes    cpc_codes  \
# 0         2012-10-03  ...  General Electric Co  [G16H10/60]  [G16H10/60]
# 1         2012-10-03  ...  General Electric Co  [G16H10/60]  [G16H10/60]
# 2         2012-10-03  ...  General Electric Co  [G16H10/60]  [G16H10/60]
# 3         2012-10-03  ...  General Electric Co  [G16H10/60]  [G16H10/60]
# 4         2012-10-03  ...  General Electric Co  [G16H10/60]  [G16H10/60]
# ..               ...  ...                  ...          ...          ...
# 495       2012-10-03  ...  General Electric Co  [G16H10/60]  [G16H10/60]
# 496       2012-10-03  ...  General Electric Co  [G16H10/60]  [G16H10/60]
# 497       2012-10-03  ...  General Electric Co  [G16H10/60]  [G16H10/60]
# 498       2012-10-03  ...  General Electric Co  [G16H10/60]  [G16H10/60]
# 499       2012-10-03  ...  General Electric Co  [G16H10/60]  [G16H10/60]
#
#     claim_count independent_claim_count  backward_citation_count  \
# 0            22                       4                       60
# 1            22                       4                       60
# 2            22                       4                       60
# 3            22                       4                       60
# 4            22                       4                       60
# ..          ...                     ...                      ...
# 495          22                       4                       60
# 496          22                       4                       60
# 497          22                       4                       60
# 498          22                       4                       60
# 499          22                       4                       60
#
#      forward_citation_count  legal_status  detected_language  \
# 0                         0        Status                 zh
# 1                         0        Status                 zh
# 2                         0        Status                 zh
# 3                         0        Status                 zh
# 4                         0        Status                 zh
# ..                      ...           ...                ...
# 495                       0        Status                 zh
# 496                       0        Status                 zh
# 497                       0        Status                 zh
# 498                       0        Status                 zh
# 499                       0        Status                 zh
#
#                                           claims_clean
# 0    A computer-implemented method of receiving dat...
# 1    A computer-implemented method of receiving dat...
# 2    A computer-implemented method of receiving dat...
# 3    A computer-implemented method of receiving dat...
# 4    A computer-implemented method of receiving dat...
# ..                                                 ...
# 495  A computer-implemented method of receiving dat...
# 496  A computer-implemented method of receiving dat...
# 497  A computer-implemented method of receiving dat...
# 498  A computer-implemented method of receiving dat...
# 499  A computer-implemented method of receiving dat...
#
# [500 rows x 22 columns]

# %%
df.duplicated(subset="patent_id").sum()
# Out:
# np.int64(0)

# %%
df.to_csv(
    "../data/processed/cleaned_patent_data.csv",
    index=False
)

# %%
# Handle Missing Abstracts
df[df['abstract'].isnull()][['patent_id',
                             'title',
                             'description',
                             'claims']].head()
# Out:
# Empty DataFrame
# Columns: [patent_id, title, description, claims]
# Index: []

# %%
# use english abstract if available
df['abstract'] = df['abstract'].fillna(df['abstract_en'])

# %%
# Since both abstract and abstract_en have the same missing count, some patents still won't have abstracts.

# For those remaining patents, use the first few hundred characters of the description:

df['abstract'] = df.apply(
    lambda row:
    row['description'][:1000]
    if pd.isna(row['abstract']) and pd.notna(row['description'])
    else row['abstract'],
    axis=1
)

# %%
# Handle Missing Descriptions
df['description'] = df['description'].fillna('')

# %%
df.isnull().sum()
# Out:
# source_url                  0
# patent_id                   0
# title                       0
# title_en                    0
# abstract                    0
# abstract_en                 0
# description                 0
# claims                      0
# filing_date                 6
# publication_date            6
# country                     0
# assignee_original          22
# assignee_en                22
# ipc_codes                   0
# cpc_codes                   0
# claim_count                 0
# independent_claim_count     0
# backward_citation_count     0
# forward_citation_count      0
# legal_status                0
# detected_language           0
# claims_clean                0
# dtype: int64

# %% [markdown]
# ## For classification and clustering, create a combined text field:

# %% [markdown]
# - Creating a combined text field is a standard preprocessing step in Natural Language Processing (NLP). It merges multiple text columns into a single string for each row.Why Use This Code?Prevents Errors: .fillna('') replaces missing values (NaN) with empty spaces so the concatenation does not return an error or result in a missing output.Consolidates Context: It groups all relevant textual data (title, abstract, and claims) into one place for the machine learning model to read.
#
# - Why Use This Code?Prevents Errors: .fillna('') replaces missing values (NaN) with empty spaces so the concatenation does not return an error or result in a missing output.Consolidates Context: It groups all relevant textual data (title, abstract, and claims) into one place for the machine learning model to read.
#
# - Key Use Cases
# 1. Maximizing Information Density for ClassificationIn patent or academic paper classification, looking at the title alone is not enough to understand the topic.The abstract provides the summary.The claims provide technical boundaries.Combining them gives your classifier (like BERT, Logistic Regression, or LightGBM) the complete context to predict the correct category or tag.
#
# 2. Creating Complete Embeddings for ClusteringClustering algorithms (like K-Means) group similar documents based on text embeddings.If you generate embeddings for each column separately, you look at data in silos.By feeding combined_text into a vectorizer (like TF-IDF or Sentence-Transformers), you create a single, high-dimensional vector that captures the entire essence of the document.
#
# 3. Improving Document Search and RetrievalIf you are building a search engine, searching across multiple distinct columns is computationally heavy. Searching a single combined_text field speeds up keyword matching and semantic search queries.
#
# - To help tailor the next steps, let me know:What machine learning model or embedding technique (e.g., TF-IDF, BERT) do you plan to use?Are you facing any token length limits (since combining text can make strings very long)?Is this for patent data, academic papers, or another type of document?8 sitesCrafting Clean Narratives With NLP: A Deep Dive into Text Data Preprocessing with Python, Pandas…2 Dec 2023 — Filling Missing Values: The fillna() method is used to fill missing values with a specified placeholder (in this case, an empty st...Level Up CodingPart 6: Data Manipulation in String and Text Processing15 Feb 2026 — One thing to keep in mind: string operations on missing values (NaN) return NaN. They don't throw errors, which is good. But you n...MediumData Cleaning and Preprocessing: Top 15 Interview Questions and Answers for Data Scientists2 Dec 2024 — Explanation: The fillna() function replaces missing values with a specified value. Using the column mean ensures no empty spots, a...MediumShow all

# %%
# For classification and clustering, create a combined text field:
df['combined_text'] = (
    df['title'].fillna('') + ' ' +
    df['abstract'].fillna('') + ' ' +
    df['claims'].fillna('')
)

# %%
df.head(3)
# Out:
#                                             source_url      patent_id  \
# 0    https://patents.google.com/patent/CN102708128A/en   CN102708128A
# 500  https://patents.google.com/patent/KR102798691B...  KR102798691B1
# 501  https://patents.google.com/patent/US11913937B2/en   US11913937B2
#
#                                                  title  \
# 0    Methods and systems for receiving, mapping and...
# 500  Electrocardiogram interpretating system with u...
# 501  Method and device for automatically tracking u...
#
#                                               title_en  \
# 0    Methods and systems for receiving, mapping and...
# 500  Electrocardiogram interpretating system with u...
# 501  Method and device for automatically tracking u...
#
#                                               abstract  \
# 0    The invention is entitled "Methods and systems...
# 500  The present invention comprises an electrocard...
# 501  A method of automatically tracking urine in a ...
#
#                                            abstract_en  \
# 0    The invention is entitled "Methods and systems...
# 500  The present invention comprises an electrocard...
# 501  A method of automatically tracking urine in a ...
#
#                                            description  \
# 0    The invention is entitled "Methods and systems...
# 500  The present invention comprises an electrocard...
# 501  CROSS-REFERENCE TO RELATED PATENT APPLICATIONS...
#
#                                                 claims filing_date  \
# 0    1.一种接收与卫生保健消息结构的不同版本关联的数据输入的计算机实现的方法，包括： 1. A ...  2012-02-21
# 500  1유도 이상의 심전도를 측정하여 심전도 데이터를 생성하는 심전도 측정부; 상기 1유...  2021-08-17
# 501  1. A method of automatically tracking urine in...  2021-08-13
#
#     publication_date  ...     ipc_codes     cpc_codes claim_count  \
# 0         2012-10-03  ...   [G16H10/60]   [G16H10/60]          22
# 500       2023-02-24  ...  [A61B5/0006]  [A61B5/0006]           5
# 501       2021-12-02  ...  [G01N33/493]  [G01N33/493]          20
#
#     independent_claim_count backward_citation_count  forward_citation_count  \
# 0                         4                      60                       0
# 500                       5                      62                       0
# 501                       3                      81                       0
#
#      legal_status  detected_language  \
# 0          Status                 zh
# 500        Status                 ko
# 501        Status                 en
#
#                                           claims_clean  \
# 0    A computer-implemented method of receiving dat...
# 500  An electrocardiogram measuring unit that gener...
# 501  A method of automatically tracking urine in a ...
#
#                                          combined_text
# 0    Methods and systems for receiving, mapping and...
# 500  Electrocardiogram interpretating system with u...
# 501  Method and device for automatically tracking u...
#
# [3 rows x 23 columns]

# %% [markdown]
# ###

# %% [markdown]
# ### Check for completely empty documents:

# %%
empty_docs = df['combined_text'].str.strip().eq('').sum()

print("Empty documents:", empty_docs)
# Out:
# Empty documents: 0

# %%
# Remove patents with no useful text
df = df[~(
    df['abstract'].isna() &
    (df['claims'].str.strip() == '')
)]

# %%
df.isnull().sum()
# Out:
# source_url                  0
# patent_id                   0
# title                       0
# title_en                    0
# abstract                    0
# abstract_en                 0
# description                 0
# claims                      0
# filing_date                 6
# publication_date            6
# country                     0
# assignee_original          22
# assignee_en                22
# ipc_codes                   0
# cpc_codes                   0
# claim_count                 0
# independent_claim_count     0
# backward_citation_count     0
# forward_citation_count      0
# legal_status                0
# detected_language           0
# claims_clean                0
# combined_text               0
# dtype: int64

# %% [markdown]
# ### Basic Text statistics
#
# - Patent documents often contain scraping errors or outliers

# %%
# abstract length
df['abstract_length'] = (
    df['abstract']
    .fillna('')
    .apply(len)
)

df['abstract_length'].describe()
# Out:
# count    18360.000000
# mean       943.215033
# std        394.987524
# min          0.000000
# 25%        718.000000
# 50%        964.000000
# 75%       1202.000000
# max       6878.000000
# Name: abstract_length, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['abstract_length'], bins=30)
plt.show()

# %%
# word count in abstract
df['word_count'] = df['abstract'].astype(str).apply(
    lambda x: len(x.split())
)

df['word_count'].describe()
# Out:
# count    18360.000000
# mean       142.372767
# std         60.236170
# min          0.000000
# 25%        109.000000
# 50%        146.000000
# 75%        179.000000
# max        935.000000
# Name: word_count, dtype: float64

# %%
# claim characters length per patent
df['claims_length_chars'] = df['claims'].fillna('').apply(len)

df[['patent_id', 'claims_length_chars']]
# Out:
#            patent_id  claims_length_chars
# 0       CN102708128A                 9039
# 500    KR102798691B1                 4798
# 501     US11913937B2                 6604
# 502      JP7095207B2                10617
# 503     CN108538402A                 7737
# ...              ...                  ...
# 18965   CN106336990A                 7283
# 18966   CN106305936A                 1431
# 18967   CN106262900A                 2389
# 18968   CN103919802B                 2593
# 18969   CN103947806B                 1849
#
# [18360 rows x 2 columns]

# %% [markdown]
# - Patent Intelligence project, I recommend using claims_word_count because it can later be used as:
#
# An EDA feature
# An ML feature
# A complexity indicator
# A patent quality indicator (along with citation counts)

# %%
# claim words length per patent
df['claims_word_count'] = (
    df['claims']
    .fillna('')
    .apply(lambda x: len(str(x).split()))
)

df[['patent_id', 'claims_word_count']]
# Out:
#            patent_id  claims_word_count
# 0       CN102708128A               1132
# 500    KR102798691B1                755
# 501     US11913937B2               1097
# 502      JP7095207B2               1306
# 503     CN108538402A               1114
# ...              ...                ...
# 18965   CN106336990A               1165
# 18966   CN106305936A                224
# 18967   CN106262900A                368
# 18968   CN103919802B                328
# 18969   CN103947806B                299
#
# [18360 rows x 2 columns]

# %%
# claims length
df['claims_length'] = \
df['claims'].astype(str).apply(len)

df['claims_length'].describe()
# Out:
# count     18360.000000
# mean       7688.979466
# std        9434.509263
# min           0.000000
# 25%        3518.750000
# 50%        6166.000000
# 75%        9347.500000
# max      547217.000000
# Name: claims_length, dtype: float64

# %%
sns.boxplot(x=df['claims_length'])
plt.show()

# %% [markdown]
# ### converting dates

# %%
df['publication_date'] = pd.to_datetime(
    df['publication_date']
)
df['publication_date']

# df['year'] = df['publication_date'].dt.year
# df['year']
# Out:
# 0       2012-10-03
# 500     2023-02-24
# 501     2021-12-02
# 502     2020-05-28
# 503     2018-09-14
#            ...
# 18965   2017-01-18
# 18966   2017-01-11
# 18967   2017-01-04
# 18968   2014-07-16
# 18969   2014-07-30
# Name: publication_date, Length: 18360, dtype: datetime64[ns]

# %%
# filing date
df['filing_date'] = pd.to_datetime( df['filing_date'])
df['filing_year'] = df['filing_date'].dt.year
df[['filing_date', 'filing_year']]
# Out:
#       filing_date  filing_year
# 0      2012-02-21       2012.0
# 500    2021-08-17       2021.0
# 501    2021-08-13       2021.0
# 502    2019-11-05       2019.0
# 503    2018-04-16       2018.0
# ...           ...          ...
# 18965  2016-08-24       2016.0
# 18966  2016-08-23       2016.0
# 18967  2016-08-21       2016.0
# 18968  2013-01-11       2013.0
# 18969  2014-05-07       2014.0
#
# [18360 rows x 2 columns]

# %% [markdown]
# ### Top assignees
# - this provides competitor intelligence

# %%
top_companies = df['assignee_en'].value_counts().head(10)

top_companies.plot(kind='bar')
plt.show()

# %% [markdown]
# ### Text EDA

# %%
# most frequent words in abstract - These can later be added to custom stopwords.
text = " ".join(df['abstract'].astype(str))
text

from collections import Counter

words = text.lower().split()

Counter(words).most_common(30)
# Out:
# [('the', 229447),
#  ('and', 112050),
#  ('a', 105916),
#  ('of', 102443),
#  ('to', 65268),
#  ('is', 41211),
#  ('for', 28831),
#  ('in', 28226),
#  ('data', 20202),
#  ('an', 20134),
#  ('by', 18310),
#  ('information', 17978),
#  ('with', 16983),
#  ('medical', 16921),
#  ('on', 16172),
#  ('health', 15162),
#  ('invention', 14455),
#  ('method', 12496),
#  ('patient', 11982),
#  ('system', 11826),
#  ('that', 11754),
#  ('are', 11671),
#  ('can', 11639),
#  ('parts', 11408),
#  ('or', 10592),
#  ('be', 10479),
#  ('user', 9929),
#  ('from', 9195),
#  ('device', 8848),
#  ('care', 8755)]

# %%
# most frequent words in abstract - These can later be added to custom stopwords.
claims_text = " ".join(df['claims'].astype(str))
claims_text

from collections import Counter

words = claims_text.lower().split()

Counter(words).most_common(30)
# Out:
# [('the', 1911829),
#  ('of', 809316),
#  ('a', 661993),
#  ('and', 512232),
#  ('to', 498160),
#  ('is', 333647),
#  ('in', 253708),
#  ('claim', 178464),
#  ('for', 173411),
#  ('wherein', 167968),
#  ('data', 159929),
#  ('or', 151676),
#  ('one', 144807),
#  ('information', 142213),
#  ('상기', 129303),
#  ('by', 123989),
#  ('an', 123136),
#  ('with', 122126),
#  ('method', 120538),
#  ('on', 119905),
#  ('first', 110875),
#  ('at', 108062),
#  ('according', 105838),
#  ('medical', 102981),
#  ('that', 96903),
#  ('patient', 94147),
#  ('system', 91336),
#  ('from', 83340),
#  ('second', 82292),
#  ('device', 79101)]

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.9.6)
# Requirement already satisfied: pillow in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from wordcloud) (12.2.0)
# Requirement already satisfied: numpy>=1.19.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from wordcloud) (2.2.6)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from wordcloud) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/asawaribrijeshtalathi/Library/Python/3.10/lib/python/site-packages (from matplotlib->wordcloud) (26.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.63.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/asawaribrijeshtalathi/Library/Python/3.10/lib/python/site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.3.2)
# Requirement already satisfied: six>=1.5 in /Users/asawaribrijeshtalathi/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# WARNING: You are using pip version 21.2.4; however, version 26.1.2 is available.
# You should consider upgrading via the '/usr/local/bin/python3.10 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Word Count Analysis

# %%
df['word_count'] = (
    df['combined_text']
    .apply(lambda x: len(str(x).split()))
)

df['word_count'].describe()
# Out:
# count     18360.000000
# mean       1326.532081
# std        1504.666141
# min           4.000000
# 25%         698.000000
# 50%        1092.500000
# 75%        1580.000000
# max      106130.000000
# Name: word_count, dtype: float64

# %% [markdown]
# ### Detect Outliers

# %%
# Find extremely short patents
short_patents = df[df['word_count'] < 50][
    ['patent_id',
     'title',
     'word_count']
]

short_patents
# Out:
#               patent_id                                              title  \
# 9297     KR20210141823A  Method and apparatus for the treatment of pain...
# 11088   SG11202105838TA  Providing personalized health care information...
# 11762    WO2010132393A3  System and method for matching health care pro...
# 13550  BR112017015045A2        health care data exchange method and system
# 16217       CA3301717A1                 Treatment of lag-3 positive tumors
# 17333       WO0106468A1                           Error 404 (Not Found)!!1
# 17341      WO03015656A2                           Error 404 (Not Found)!!1
# 17344      WO03042781A2                           Error 404 (Not Found)!!1
# 18558       WO9835284A2                           Error 404 (Not Found)!!1
# 18564       WO9746143A1                           Error 404 (Not Found)!!1
# 18569       WO9835284A9                           Error 404 (Not Found)!!1
#
#        word_count
# 9297           49
# 11088           8
# 11762          46
# 13550          46
# 16217           5
# 17333           4
# 17341           4
# 17344           4
# 18558           4
# 18564           4
# 18569           4

# %%
# find extremely long patents
df.nlargest(10, 'word_count')[
    ['patent_id',
     'title',
     'word_count']
]
# Out:
#               patent_id                                              title  \
# 17230     BRPI0913682A2  method for identifying dihydroxy-acid dehydrat...
# 18538      CN115337631A  A system and method that uses meals as a game,...
# 3180     WO2022178447A1  Medicament pumps with systems and methods for ...
# 13040    AU2016316758B2        Antibodies and assays for detection of CD37
# 17128    KR20250067174A  Treatment of autoimmune disorders using chimer...
# 15616   US20240282425A1  Authentication methods and systems for dispens...
# 17351  BR112019020610A2             treatment of positive tumors for lag-3
# 15076    WO2012067640A1  Methods and systems for secured global applica...
# 15452    AU2018206851A1  Fixed dosage regimens for anti-type i interfer...
# 5487     WO2018138711A2  System for continuous remote monitoring and co...
#
#        word_count
# 17230      106130
# 18538       47934
# 3180        35436
# 13040       30702
# 17128       29484
# 15616       28024
# 17351       24475
# 15076       23292
# 15452       21350
# 5487        20466

# %%
# For patent NLP, documents with fewer than 20 to 30 words are usually not useful and can often be removed.
df = df[df['word_count'] >= 30]

# %%
# analyze top assignees
df['assignee_en'].value_counts().head(15)
# Out:
# assignee_en
# Individual                                                 2939
# Koninklijke Philips NV                                      118
# Samsung Electronics Co Ltd                                  109
# International Business Machines Corp                         94
# Colgate Palmolive Co                                         89
# Huawei Technologies Co Ltd                                   76
# Cerner Innovation Inc                                        72
# General Electric Co                                          68
# Shenzhen Mindray Bio Medical Electronics Co Ltd              68
# Ping An Technology Shenzhen Co Ltd                           65
# Hill Rom Services Inc                                        62
# Fujifilm Corp                                                50
# Shenzhen Qianhai AnyCheck Information Technology Co Ltd      41
# Stryker Corp                                                 40
# Jilin University                                             39
# Name: count, dtype: int64

# %%
# analyze legal status
df['legal_status'].value_counts()
# Out:
# legal_status
# Status        15873
# Unknown         633
# Pending          30
# Active           22
# Granted          11
#               ...
# 2023-05-06        1
# 2021-05-07        1
# 2025-07-29        1
# 2024-09-09        1
# 2024-04-11        1
# Name: count, Length: 1316, dtype: int64

# %%
# analyze filing trends
df['filing_date'] = pd.to_datetime(df['filing_date'])

df['year'] = df['filing_date'].dt.year

df['year'].value_counts().sort_index().plot(
    kind='line',
    figsize=(8,5),
    marker='o'
)

plt.title('Patent Filing Trend')
plt.show()

# %% [markdown]
# ### analyzing ipc/cpc codes

# %%
# Analyze CPC codes frequency
from collections import Counter

all_cpc = []

for codes in df['cpc_codes']:
    all_cpc.extend(codes)

Counter(all_cpc).most_common(10)
# Out:
# [('A61B5/00', 1443),
#  ('G16H80/00', 1266),
#  ('G16H10/60', 673),
#  ('G16H40/20', 625),
#  ('G16H50/20', 476),
#  ('G16H40/67', 406),
#  ('G16H50/30', 390),
#  ('G16H20/10', 194),
#  ('G16H10/20', 186),
#  ('G06Q50/22', 186)]

# %% [markdown]
# ### why we are analyzingg cpc codes
# This is an excellent idea for EDA. In patent analytics, it is very common to analyze patents at two levels:
#
# 1. **Parent CPC class level** (high-level technology domains)
# 2. **Subcategory CPC code level** (specific technologies)
#
# For example:
#
# ```text
# A61B → 250 patents
#     A61B5/00 → 120 patents
#     A61B5/024 → 60 patents
#     A61B34/00 → 40 patents
#
# G16H → 180 patents
#     G16H50/20 → 80 patents
#     G16H50/30 → 50 patents
#     G16H40/60 → 30 patents
# ```

# %%
# count parent cpc classes
# Extract the parent class from each CPC code.
from collections import Counter

parent_classes = []

for patent_codes in df['cpc_codes']:
    for code in patent_codes:

        # Extract parent class
        parent = code.split('/')[0]

        # For G16H50/20 -> G16H
        if len(parent) > 4:
            parent = parent[:4]

        parent_classes.append(parent)

parent_count = Counter(parent_classes)

print(parent_count.most_common())
# Out:
# [('G16H', 5968), ('A61B', 3289), ('G06Q', 1162), ('G06F', 805), ('A23L', 440), ('A61K', 324), ('H04L', 195), ('A61M', 160), ('A23V', 151), ('A61H', 147), ('G08B', 127), ('A61N', 126), ('G06T', 124), ('G01N', 121), ('A61G', 117), ('G06N', 113), ('C12G', 94), ('A61C', 92), ('H04N', 82), ('G06K', 75), ('G06V', 70), ('H04W', 70), ('A61F', 70), ('A46B', 69), ('G09B', 64), ('G10L', 61), ('A23F', 59), ('A61J', 56), ('A63B', 45), ('Y02P', 39), ('A47G', 38), ('A01K', 36), ('A43B', 36), ('Y02A', 35), ('A47C', 34), ('A41D', 32), ('H04M', 28), ('G16B', 27), ('A61L', 25), ('A21D', 25), ('G16Z', 23), ('G01S', 21), ('C07K', 19), ('G07C', 18), ('C12N', 18), ('D01F', 18), ('A23G', 18), ('G07F', 16), ('C12Q', 15), ('B25J', 15), ('G05B', 15), ('C08G', 15), ('A23K', 15), ('A23C', 15), ('H04R', 14), ('A45D', 13), ('A45C', 13), ('A47K', 13), ('A23D', 13), ('G01R', 11), ('F24F', 11), ('D03D', 11), ('G02B', 10), ('B60W', 10), ('G01L', 10), ('E04H', 10), ('C12M', 10), ('G01C', 9), ('D04B', 9), ('H05K', 8), ('H04B', 8), ('A44C', 8), ('C04B', 8), ('H04Q', 7), ('A42B', 7), ('B65D', 7), ('H02J', 7), ('A61Q', 7), ('D02G', 7), ('A24B', 7), ('B65B', 7), ('B32B', 7), ('D06M', 7), ('C12J', 7), ('G05D', 6), ('E03D', 6), ('G01J', 6), ('B29C', 6), ('A61D', 6), ('A62B', 6), ('B05B', 6), ('B01D', 6), ('A01G', 6), ('A23B', 6), ('A41B', 6), ('G02C', 5), ('G01G', 5), ('G01B', 5), ('G08C', 5), ('C08L', 5), ('A41C', 5), ('C08F', 5), ('C11D', 5), ('B01L', 4), ('G01V', 4), ('H05B', 4), ('A61P', 4), ('H10F', 4), ('B60K', 4), ('C09J', 4), ('B02B', 4), ('E03C', 4), ('E05B', 4), ('A01N', 4), ('C25B', 4), ('G16C', 3), ('H03B', 3), ('C08J', 3), ('A63F', 3), ('H01Q', 3), ('E04B', 3), ('G04G', 3), ('F16M', 3), ('C23C', 3), ('A47B', 3), ('G01M', 3), ('E21B', 3), ('A23P', 3), ('Y02W', 3), ('A46D', 3), ('C08B', 3), ('G10K', 2), ('A41F', 2), ('F21V', 2), ('A45B', 2), ('H10W', 2), ('B09B', 2), ('G09G', 2), ('G01D', 2), ('G01K', 2), ('B01F', 2), ('H04K', 2), ('H03M', 2), ('B28B', 2), ('C09D', 2), ('A45F', 2), ('H02M', 2), ('A01H', 2), ('F25B', 2), ('C05G', 2), ('B02C', 2), ('G06E', 2), ('D06N', 2), ('B67C', 2), ('C12C', 2), ('D06P', 2), ('B27N', 2), ('G21F', 2), ('C11B', 2), ('A47L', 2), ('D06F', 2), ('A47J', 2), ('F21S', 2), ('H01G', 1), ('H01L', 1), ('H03F', 1), ('H01M', 1), ('G01W', 1), ('B64D', 1), ('B60H', 1), ('H02N', 1), ('G01F', 1), ('H02K', 1), ('B63J', 1), ('B63C', 1), ('G03F', 1), ('G07G', 1), ('B66F', 1), ('F16D', 1), ('G04C', 1), ('E04F', 1), ('B62D', 1), ('H10K', 1), ('B43L', 1), ('B08B', 1), ('H01H', 1), ('A63H', 1), ('B29D', 1), ('G05F', 1), ('D06C', 1), ('H02G', 1), ('G09F', 1), ('D01B', 1), ('B43K', 1), ('A24F', 1), ('G08G', 1), ('C01B', 1), ('G11B', 1), ('F03B', 1), ('C22C', 1), ('F21K', 1), ('B60N', 1), ('F04B', 1), ('G01T', 1), ('C12Y', 1), ('B66B', 1), ('C02F', 1), ('C05C', 1), ('B65G', 1), ('F16K', 1), ('E04D', 1), ('Y02B', 1), ('F26B', 1), ('A62C', 1)]

# %% [markdown]
# ### Create Technology Categories

# %% [markdown]
# #### create a parent cpc class

# %%
# Each patent should have its own list of parent CPC codes.
# def extract_parent_cpc(cpc_list):
#     parent_codes = []

#     for code in cpc_list:
#         parent = code.split("/")[0]

#         if len(parent) > 4:
#             parent = parent[:4]

#         parent_codes.append(parent)

#     # Remove duplicates while preserving order
#     return list(dict.fromkeys(parent_codes))

# df["parent_cpc"] = df["cpc_codes"].apply(extract_parent_cpc)

# %% [markdown]
# #### Verify the new column

# %%
# df[["cpc_codes", "parent_cpc"]].head(10)

# %% [markdown]
# #### define cpc groups

# %%
# AI_CODES = {
#     "G06N",
#     "G06V",
#     "G06T",
#     "G10L",
#     "G16B"
# }

# DIAGNOSTIC_CODES = {
#     "A61B",
#     "G01N",
#     "A61C",
#     "C12Q"
# }

# REMOTE_CODES = {
#     "H04L",
#     "H04M",
#     "H04W",
#     "H04Q",
#     "H04B",
#     "G08B",
#     "G01S"
# }

# WEARABLE_CODES = {
#     "A61F",
#     "A41D",
#     "A41F",
#     "G02C",
#     "A42B",
#     "A45D"
# }

# THERAPY_CODES = {
#     "A61N",
#     "A61M",
#     "A61H",
#     "A61L",
#     "A61G",
#     "B25J"
# }

# HEALTHCARE_CODES = {
#     "G16H",
#     "G06F",
#     "G06Q"
# }

# %% [markdown]
# #### create mapping function to mao cpc codes to specific technology categories

# %%
# def map_technology_class(parent_codes):

#     # Convert list to set for fast lookup
#     codes = set(parent_codes)

#     # -------------------------------
#     # Rule 1: G16H + AI
#     # -------------------------------
#     if "G16H" in codes and len(codes & AI_CODES) > 0:
#         return "AI-enabled Devices"

#     # -------------------------------
#     # Rule 2: G16H + Diagnostic
#     # -------------------------------
#     if "G16H" in codes and len(codes & DIAGNOSTIC_CODES) > 0:
#         return "Diagnostic Devices"

#     # -------------------------------
#     # Rule 3: G16H + Remote Monitoring
#     # -------------------------------
#     if "G16H" in codes and len(codes & REMOTE_CODES) > 0:
#         return "Remote Monitoring"

#     # -------------------------------
#     # Rule 4: G16H + Wearables
#     # -------------------------------
#     if "G16H" in codes and len(codes & WEARABLE_CODES) > 0:
#         return "Wearables"

#     # -------------------------------
#     # Rule 5: G16H + Therapy
#     # -------------------------------
#     if "G16H" in codes and len(codes & THERAPY_CODES) > 0:
#         return "Surgical & Therapeutic Devices"

#     # -------------------------------
#     # Rule 6: Pure AI patents
#     # -------------------------------
#     if len(codes & AI_CODES) > 0:
#         return "AI-enabled Devices"

#     # -------------------------------
#     # Rule 7: Pure Diagnostic patents
#     # -------------------------------
#     if len(codes & DIAGNOSTIC_CODES) > 0:
#         return "Diagnostic Devices"

#     # -------------------------------
#     # Rule 8: Pure Remote Monitoring patents
#     # -------------------------------
#     if len(codes & REMOTE_CODES) > 0:
#         return "Remote Monitoring"

#     # -------------------------------
#     # Rule 9: Pure Wearables
#     # -------------------------------
#     if len(codes & WEARABLE_CODES) > 0:
#         return "Wearables"

#     # -------------------------------
#     # Rule 10: Pure Therapy
#     # -------------------------------
#     if len(codes & THERAPY_CODES) > 0:
#         return "Surgical & Therapeutic Devices"

#     # -------------------------------
#     # Rule 11: Remaining G16H/G06F/G06Q
#     # -------------------------------
#     if "G16H" in codes or "G06F" in codes or "G06Q" in codes:
#         return "Healthcare Information Systems"

#     # -------------------------------
#     # Rule 12: Everything else
#     # -------------------------------
#     return "Other Medical Technologies"

# %%
# apply the function
# df["technology_class"] = df["parent_cpc"].apply(map_technology_class)

# %%
# Check the class distribution
# df["technology_class"].value_counts()

# %%
# import matplotlib.pyplot as plt

# from collections import Counter

# %% [markdown]
# #### check the dataframe

# %%
# print(df.shape)
# df.head()

# %%
# df["technology_class"].value_counts()

# %%
# round(
#     df["technology_class"].value_counts(normalize=True) * 100,
#     2
# )

# %%
# class_counts = df["technology_class"].value_counts()

# plt.figure(figsize=(10,6))

# class_counts.plot(kind="bar")

# plt.title("Technology Class Distribution")

# plt.xlabel("Technology Class")

# plt.ylabel("Number of Patents")

# plt.xticks(rotation=45)

# plt.show()

# %%
# Count patents containing only G16
# g16h_only = df[
#     df["parent_cpc"].apply(
#         lambda x: set(x) == {"G16H"}
#     )
# ]

# print("Number of G16H-only patents:")

# print(len(g16h_only))

# %%
# print(
#     round(
#         len(g16h_only)/len(df)*100,
#         2
#     ),
#     "%"
# )

# %%
# Inspect G16H-only patents
# g16h_only[
#     [
#         "title",
#         "parent_cpc",
#         "technology_class"
#     ]
# ].sample(
#     15,
#     random_state=42
# )

# %% [markdown]
# ### Parent class distribution

# %% [markdown]
# ### subcategory distribution

# %%
# convert df to csv
#df.to_csv("/home/sunbeam/Desktop/AI-Driven-Medical-Devices-Intelligent-System/src/preprocessing/cleaned_patent_data.csv", index=False)

# %%
import os

output_path = "../data/processed/cleaned_patent_data.csv"

os.makedirs(
    "../data/processed",
    exist_ok=True
)

df.to_csv(
    output_path,
    index=False,
    encoding="utf-8-sig"
)

print("Saved:", output_path)
# Out:
# Saved: ../data/processed/cleaned_patent_data.csv

# %%
pd.read_csv("../data/processed/cleaned_patent_data.csv").shape
# Out:
# (18352, 30)

# %%
import os

print(os.path.abspath("../data/processed/cleaned_patent_data.csv"))
# Out:
# /Users/asawaribrijeshtalathi/Downloads/AI-Driven-Medical-Devices-Intelligent-System 3/src/data/processed/cleaned_patent_data.csv
